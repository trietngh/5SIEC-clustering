# %% [markdown]
# Normalization

# %%
import pandas as pd
import numpy as np

# Charger le dataset et afficher les premières lignes
df = pd.read_csv("./dataset/Steam_Games_2025.csv")
df.head(10)

for col in ['singleplayer', 'multiplayer']:
    if col not in df.columns:
        df[col] = 0

# %% [markdown]
# Normal columns

# %%
num_cols = [
    'required_age',
    'dlc_count',
    'metacritic_score',
    'achievements',
    'median_playtime_forever',
    'singleplayer',
    'multiplayer'
]

# %% [markdown]
# Log Scale Columns

# %%
log_cols = [
    'recommendations',
    'positive',
    'negative',
    'peak_ccu'
]

# %% [markdown]
# Banned Columns

# %%
drop_cols = [
    'appid',
    'name',
    'price',
    'release_date'
]

# %% [markdown]
# Log Transform

# %%
df[log_cols] = df[log_cols].fillna(0)
df[log_cols] = np.log1p(df[log_cols])

# %% [markdown]
# Scaling standard

# %%
cols_to_scale = num_cols + log_cols   # tes colonnes numériques + log

# calcul des moyennes et écarts types
means = df[cols_to_scale].mean()
stds  = df[cols_to_scale].std()   

# normalisation "standard"
num_scaled_df = (df[cols_to_scale] - means) / stds

# smatrice numpy pour le clustering :
X_scaled = num_scaled_df.values

# %% [markdown]
# Test

# %%
num_scaled_df.head()
# Out:
#    required_age  dlc_count  metacritic_score  achievements  \
# 0     -0.106412   0.026343         -0.200981     -0.119541
# 1     -0.106412  -0.038795         -0.200981      0.100559
# 2     -0.106412   0.091481          6.029394     -0.125654
# 3      9.745268  -0.038795          6.444753      0.345114
# 4      9.745268   0.547451         -0.200981     -0.125654
#
#    median_playtime_forever  singleplayer  multiplayer  recommendations  \
# 0                 0.574476           NaN          NaN         5.421524
# 1                -0.013031           NaN          NaN         5.062773
# 2                 0.088937           NaN          NaN         3.218734
# 3                 0.793286           NaN          NaN         5.078238
# 4                 0.263350           NaN          NaN         4.910544
#
#    positive  negative   peak_ccu
# 0  5.496547  6.197496  11.237581
# 1  4.819589  6.145190  10.677481
# 2  4.943237  5.727255  10.591530
# 3  4.880325  5.426068   9.304888
# 4  4.712594  5.357251   9.081765

# %% [markdown]
# Test moyenne nulle

# %%
num_scaled_df.std().round(3)
# Out:
# required_age               1.0
# dlc_count                  1.0
# metacritic_score           1.0
# achievements               1.0
# median_playtime_forever    1.0
# singleplayer               NaN
# multiplayer                NaN
# recommendations            1.0
# positive                   1.0
# negative                   1.0
# peak_ccu                   1.0
# dtype: float64

# %% [markdown]
# Test Moyenne nulle

# %%
num_scaled_df.mean().round(3)
# Out:
# required_age              -0.0
# dlc_count                  0.0
# metacritic_score           0.0
# achievements               0.0
# median_playtime_forever    0.0
# singleplayer               NaN
# multiplayer                NaN
# recommendations           -0.0
# positive                   0.0
# negative                   0.0
# peak_ccu                  -0.0
# dtype: float64
